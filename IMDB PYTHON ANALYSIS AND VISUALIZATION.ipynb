# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('IMDB-Movie-Data.csv')
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.tail(5)
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df.sample(10)
# Out:
#      Rank                            Title                     Genre  \
# 490   491                       Stake Land       Drama,Horror,Sci-Fi
# 917   918               The Girl Next Door        Crime,Drama,Horror
# 620   621                             Dope        Comedy,Crime,Drama
# 526   527                          Elysium       Action,Drama,Sci-Fi
# 306   307  Alice Through the Looking Glass  Adventure,Family,Fantasy
# 150   151                          The BFG  Adventure,Family,Fantasy
# 647   648                         Tall Men   Fantasy,Horror,Thriller
# 834   835                     The Dictator                    Comedy
# 143   144                             Room                     Drama
# 85     86                   Jurassic World   Action,Adventure,Sci-Fi
#
#                                            Description           Director  \
# 490  Martin was a normal teenage boy before the cou...         Jim Mickle
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
print(f"Numbers of Rows: {df.shape[0]}\nNumbers of Columns: {df.shape[1]}")
# Out:
# Numbers of Rows: 1000
# Numbers of Columns: 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# ## Dealing with Missing Data

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df['Revenue (Millions)'].mean()
# Out:
# 82.95637614678898

# %%
avg_revenue = np.round(df['Revenue (Millions)'].mean(), 2)
avg_metascore = np.round(df['Metascore'].mean(), 2)

# %%
Average of Revenue:print("A",avg_revenue)
Average of Metascore:print("Average of Metascore:",avg_metascore)
# Out:
# Average of Revenue: 82.96
# Average of Metascore: 58.99

# %%
# fill all missing Data in Revenue
df['Revenue (Millions)'].fillna(avg_revenue, inplace=True)

# fill all missing Data in Metascore
df['Metascore'].fillna(avg_metascore, inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# remove duplicates
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## Analysis and Visualization

# %% [markdown]
# #### 1. Display Title of the Movie Having Runtime Greater than or equal to 180 Minutes

# %%
mask = df['Runtime (Minutes)'] >= 180

df[mask][['Title']]
# Out:
#                        Title
# 82   The Wolf of Wall Street
# 88         The Hateful Eight
# 311           La vie d'Adèle
# 828               Grindhouse
# 965            Inland Empire

# %% [markdown]
# #### 2. In Which  year There was a highest Average voting

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.loc[:, ['Year','Votes']]
# Out:
#      Year   Votes
# 0    2014  757074
# 1    2012  485820
# 2    2016  157606
# 3    2016   60545
# 4    2016  393727
# ..    ...     ...
# 995  2015   27585
# 996  2007   73152
# 997  2008   70699
# 998  2014    4881
# 999  2016   12435
#
# [1000 rows x 2 columns]

# %%
highest_avg_voting = np.round(df.groupby(['Year'])['Votes'].mean().sort_values(ascending=False), 2)

# %%
print(highest_avg_voting)
# Out:
# Year
# 2012    285226.09
# 2008    275505.38
# 2006    269289.95
# 2009    255780.65
# 2010    252782.32
# 2007    244331.04
# 2011    240790.30
# 2013    219049.65
# 2014    203930.22
# 2015    115726.22
# 2016     48591.75
# Name: Votes, dtype: float64

# %%
type(highest_avg_voting)
# Out:
# pandas.core.series.Series

# %%
highest_avg_voting.plot(kind='bar')

plt.xlabel("Year")
plt.ylabel("Average Voting")
plt.title("Highest Average Voting by Year")
plt.show()

# %%
sns.barplot(data=df, x='Year', y='Votes')

plt.xlabel("Year")
plt.ylabel("Average Voting")
plt.title("Highest Average Voting by Year")
plt.show()

# %%
values = list(highest_avg_voting.values)

# %%
plt.pie(highest_avg_voting, labels=values, colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown']);

# %% [markdown]
# #### 2. In Which  year There was a highest Average Revenue

# %%
highest_avg_revenue = np.round(df.groupby(['Year'])['Revenue (Millions)'].mean().sort_values(ascending=False), 2)

# %%
print(highest_avg_revenue)
# Out:
# Year
# 2009    110.28
# 2012    107.97
# 2010    103.98
# 2008     98.77
# 2011     87.54
# 2007     87.51
# 2013     86.98
# 2006     86.14
# 2014     84.99
# 2015     78.86
# 2016     63.45
# Name: Revenue (Millions), dtype: float64

# %%
sns.barplot(data=df, x='Year', y='Revenue (Millions)')

plt.xlabel("Year")
plt.ylabel("Average Voting")
plt.title("Highest Average Voting by Year")
plt.show()

# %% [markdown]
# #### Numbers of Movies Per Year

# %%
no_of_movies_per_year = df.groupby(df['Year'])['Title'].count().sort_values(ascending=False)
print(no_of_movies_per_year)
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: Title, dtype: int64

# %%
sns.barplot(no_of_movies_per_year.reset_index(), x='Year', y='Title')

plt.xlabel("Year")
plt.ylabel("Count of Movies")
plt.title("Count of Movies by Year")
plt.show()

# %%
print(f"The Year {no_of_movies_per_year.index[0]} has the highest number of movies with a count of {no_of_movies_per_year.max()}")
# Out:
# The Year 2016 has the highest number of movies with a count of 297

# %% [markdown]
# #### Does Rating Affect Revenue?

# %%
df.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_6636\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.252995 -0.117558           0.247831  0.189524  0.607937
# Metascore          -0.185157 -0.076076           0.202238  0.604721  0.318108
#
#                     Revenue (Millions)  Metascore
# ...

# %%
#find line of best fit
a, b = np.polyfit(df['Rating'], df['Revenue (Millions)'], 1)

# %%
plt.scatter(x=df['Rating'], y=df['Revenue (Millions)'])

#add line of best fit to plot
plt.plot(df['Rating'], a*df['Rating']+b)       

plt.xlabel("Rating")
plt.ylabel("Revenue (Millions)")
plt.title("Rating Versus Revenue")
plt.show()

# %%
def classify_rating(rating):
    if rating >= 7.5:
        return 'Excellent'
    elif rating >= 6.0:
        return 'Good'
    else:
        return 'Average'

# %%
df['Rating Category'] = df['Rating'].apply(classify_rating)

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df["Rating Category"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Rating Category'>
